# %% [markdown]
# # Introduction to Neural Networks and Deep Learning

# %% [markdown]
# ## What's the difference between Artificial Intelligence, Machine Learning and Deep Learning?
#
# **Artificial Intelligence** (AI) is a very old field of research. It started in the 1950s; at that time, the pioneers in AI were convinced that they could make machines think. The initial approach was attempting to model intellectual tasks, and program those tasks in computers. That is, in the beginning, AI was about people *hard-coding* problems that the machine tried to solve. A good example of an early AI program is computer chess. Early AI computer chess programs had **lots of rules pre-conceived by the program designers**. So although the term refers to "intelligence", these programs were not "intelligent", but just a sophisticated set of rules.
#
# * The term *neural network* was also born at that time. The initial idea was trying to mimic how a *neuron* works (or in fact, how it was thought a neuron worked when the term was coined) in the brain. As in the case of *Artificial Intelligence*, please do not be fooled by the terms. A *neural network* is just a way to compute approximation to functions. A powerful and useful way, true. But it is not any kind of "artificial brain", or anything like that.
#
# This approach is now obsolete. We now know that some tasks are so complex, that we will never be able to pre-design a system to have a good performance on those tasks. Take the example of the game of Go. Any program designed by humans to play Go was dull and could not compete against professional players. The game is so hard that is just impossible for us as humans to conceived a good Go computer player.
# * https://en.wikipedia.org/wiki/Go_(game)
#
# The modern approach to solve this kind of problems involves the use of data. This is what the *learning* part of *Deep Learning* (and *Machine Learning*) refers to. **Learning from data**. So, with this brief introduction, we can say that *Artificial Intelligence* is a broad concept that includes *Machine Learning*, that includes *Deep Learning*. *Artificial Intelligence* does not necessarily means learning from data, but Machine Learning does. And *Deep Learning* is just doing *Machine Learning* with neural networks.
#
# ![](imgs/01_ai_ml_dl.png)
#
# We will see during this course what *learning* means, and what is a *neural network*.
#
# In the case of the game of Go, all attempts to design a good Go computer player failed, until Google DeepMind created AlphaGo, a system that *learned* to play Go based on data from previous games. AlphaGo is an example that learning from data can provide computer systems that are superior to any system pre-conceived by humans.
# * Find out more about AlphaGo by watching this utterly interesting movie: https://www.alphagomovie.com/
#
# In this course, we will give our first steps on *Deep Learning* and *Neural Networks*, to start creating systems that perform complex tasks by learning from data. Instead of attempting to derive the rules by ourselves, those rules will be inferred by a neural network based on the data we provide:
#
# ![](imgs/02_rules_data.png)

# %% [markdown]
# # Deep Learning and Machine Learning: why is everyone now talking about Deep Learning?
#
# To create our system, we need data:
# * Input data points; e.g. images to recognize shapes inside the images.
# * Examples of expected output. The system will use these examples to learn from them. For the images above, we will need *labels* telling us what is in the image.
#
# The neural network will *learn* from this data. But in fact, what the network is doing is learning a *representation* of the data that makes the task much easier to solve.
#
# Let's see an example. We have the following input data (x,y coordinates for the points), and the labels of each item (the color of the point). We would like to obtain a model to separete the two classes of points:
#
# ![](imgs/03_points.png)
#
# How would you separate the points? In the current reference system, it can be a complex task. But if you change the reference system (*if you learn a new representation of the data*), the task becomes trivial:
#
# ![](imgs/04_representation.png)
#
# In Deep Learning, we learn **layers** of increasingly better representations. The **deep** in Deep Learning refers to the number of layers that we learn. Before Deep Learning, the models that we are going to see today were much shallower. The most typical form of the layer representations is **neural networks**. As we will see, **neural networks** are just chain of matrix operations -- arrays of 2 dimensions--, or more precisely, tensor operations, we will operate in dimensions higher than 2.
#
#
# * More about learning representations: https://www.bbvadata.com/not-deep-learning-learning-represent/

# %% [markdown]
# ## Neural Networks
#
# A neural network is just a stacked set of layers. Each layer is represented by a tensor, and it performs an affine transformation on each one of the layers.
# * A matrix is a 2D tensor
# * Affine transformation $\vec{y} = W\cdot\vec{x} + \vec{b}$, where $W$ is the weights tensor, $\vec{x}$ is the input data, $\vec{y}$ is the output data and $\vec{b}$ is called the bias
# * $W$ and $\vec{b}$ are model parameters that need to be found by training
#
# ![](imgs/05_nn.png)
#
# Note that this is a **linear operation**, therefore the result will be linear too. But the functions we want to learn are normally non-linear. How do we overcome this limiation? By using an **activation function**, that transforms the result from the linear operation. So, we actually do the following operation:
#
# $\vec{y} = f\left(W\cdot\vec{x} + \vec{b}\right)$
#
# There are several common activation functions, depending on the characteristics of the data and the kind of problem we want to solve. Here we will use the probably most often used activation function: **rectified linear unit**, or **relu** for friends:
#
# ![Relu plot](https://upload.wikimedia.org/wikipedia/commons/6/6c/Rectifier_and_softplus_functions.svg)
#
# (image extracted from https://en.wikipedia.org/wiki/Rectifier_(neural_networks))
#
# Relu will add the non-linearity that we need to learn arbitrary functions.
#
# We can achieve the same with many other activation functions. See the documentation of Keras for details on the available activation functions:
#  - https://keras.io/activations/
#
#
# Each layer learns a new representation of the input data, and after several layers, the representation will make it straightforward to solve the task (e.g. assiging a digit to an image of a digit).
#
# Until very recently, any attempt to train a deep neural network would not provide good results. Recent progresses (e.g. advances in hardware, new activation functions) make it possible to train very deep network, and therefore, solve problems that were unfeasible not long ago.
#
# ### Training process
#
# The parameters of the network are initially randomly assigned. Then after each pass of the network, that is, after each *epoch*, the predictions of the network is compared against the true values, applying a *loss function*. This score is used to update the parameters of the network, with a process called **backpropagation**.
# * Backpropagation is a complex process that involves calculating the gradient of the parameters of the network. For more details see: https://en.wikipedia.org/wiki/Backpropagation
# * See also this excellent and visual explanation of how backpropagation works: https://google-developers.appspot.com/machine-learning/crash-course/backprop-scroll/
#
# The training process is just an optimization process, that is normally done using a gradient descent-based algorithm. The values of gradients are computed using the backpropagation algorithm. Each epoch will make the loss score to be lower, and the predictions to be better.
#
# ![](imgs/06_optim.png)
#
# In practice, we have to fine tune the number of epochs (and other parameters), until we obtain a result that is good enough for our purpose. In fact, if the number of epochs is too high, our model may **overfit** the training data. In that case, it will perform worsely when the model is exposed to data that it  has not seen previously.
# * Fine tuning the number of epochs, and other parameters (e.g. the number and shape of the layers) is known as **hyperparameters optimization**, or **hyperparameters tuning**
# * The parameters of the model are the $W$ and $b$ values of each layer, and those are determined by training.
#
# ## Hyperparameters tuning
#
# In summary, when we are trying to obtain a deep learning model, the process that we will follow is:
# * Decide on the architecture of the network (number of layers, type of each layer, size of each layer)
# * Decide on the activation functions on each layer
# * Decide on the parameters related to the optimization process (e.g. learning rate)
# * Decide on the loss function that we will use
# * Decide on the metrics that we will use to evaluate the performance of the model
# * Decide on the training parameters (number of epochs, batch size)
# * Decide on how to split the data between training, validation and test sets.
#
# We obtain feedback for those decisions with the results of the training applied to the validation set. We train once, change some of the hyperparameters, train again, decide if that's better, and we keep going until we have found a model that is satisfactory enough for our purposes.
#
# After that, we finally evaluate the model on the test set.

# %% [markdown]
# ## Our first neural network
#
# Let's start with an easy example. We are going to produce some synthetic data, and will try to predict the function that generates the data. We will add some noise, to make the problem more difficult.
#
# The function we are going to try to predict is
#
# $\displaystyle y = 3*x + 2$

# %%
# %pylab inline
plt.style.use('seaborn-talk')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def plot_metric(history, metric):
    history_dict = history.history
    values = history_dict[metric]
    if 'val_' + metric in history_dict.keys():  
        val_values = history_dict['val_' + metric]

    epochs = range(1, len(values) + 1)

    if 'val_' + metric in history_dict.keys():  
        plt.plot(epochs, val_values, label='Validation')
    plt.semilogy(epochs, values, label='Training')

    if 'val_' + metric in history_dict.keys():  
        plt.title('Training and validation %s' % metric)
    else:
        plt.title('Training %s' % metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend()

    plt.show()

# %% [markdown]
# ### Preparar los datos

# %%
x_train = np.linspace(0, 100, 1000)
y_train = 3*x_train + 2

# %%
plot(x_train, y_train)

# %% [markdown]
# ### Now another more complex function
#
# Let's try to fit a parabollic function
#
# $\displaystyle y = -2x^2 + x + 1$

# %%
from keras import layers
# Out:
# Using TensorFlow backend.

# %%
from keras import models

# %%
m = models.Sequential()

# %%
m = models.Sequential()
m.add(layers.Dense(units = 64,activation = "relu",input_shape = (1,)))
m.add(layers.Dense(units = 32,activation = "relu"))
m.add(layers.Dense(units = 1,activation = None))

# %%
m.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 64)                128
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 2,241
# Trainable params: 2,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import losses, optimizers, metrics

# %%
m.compile(loss = losses.mse,optimizer = optimizers.rmsprop(),metrics = [metrics.mean_absolute_error])

# %%
h = m.fit(x = x_train,y = y_train,batch_size = 100,epochs = 120,validation_split = 0.2)

# %%
def build():
  m = models.Sequential()
  m.add(layers.Dense(units = 64,activation = "relu",input_shape = (1,)))
  m.add(layers.Dense(units = 32,activation = "relu"))
  m.add(layers.Dense(units = 16,activation = "relu"))
  m.add(layers.Dense(units = 1,activation = None))
  m.compile(loss = losses.mse,optimizer = optimizers.rmsprop(),metrics = [metrics.mean_absolute_error])
  return m

# %%
m = build()
h = m.fit(x = x_train,y = y_train,batch_size = 100,epochs = 120,validation_split = 0.2)
# Out:
# Train on 800 samples, validate on 200 samples
# Epoch 1/120
# 800/800 [==============================] - 0s 287us/step - loss: 18352.7100 - mean_absolute_error: 117.7838 - val_loss: 66212.3730 - val_mean_absolute_error: 256.7971
# Epoch 2/120
# 800/800 [==============================] - 0s 37us/step - loss: 16689.8206 - mean_absolute_error: 112.3295 - val_loss: 59082.1738 - val_mean_absolute_error: 242.5766
# Epoch 3/120
# 800/800 [==============================] - 0s 36us/step - loss: 14793.1472 - mean_absolute_error: 105.7458 - val_loss: 51539.0371 - val_mean_absolute_error: 226.5630
# Epoch 4/120
# 800/800 [==============================] - 0s 36us/step - loss: 12775.1171 - mean_absolute_error: 98.2479 - val_loss: 43929.9609 - val_mean_absolute_error: 209.1710
# Epoch 5/120
# 800/800 [==============================] - 0s 34us/step - loss: 10737.6611 - mean_absolute_error: 90.0542 - val_loss: 36083.6338 - val_mean_absolute_error: 189.5729
# Epoch 6/120
# 800/800 [==============================] - 0s 44us/step - loss: 8636.9901 - mean_absolute_error: 80.7173 - val_loss: 28060.4492 - val_mean_absolute_error: 167.1740
# Epoch 7/120
# 800/800 [==============================] - 0s 39us/step - loss: 6540.5858 - mean_absolute_error: 70.2197 - val_loss: 20426.0576 - val_mean_absolute_error: 142.6311
# Epoch 8/120
# 800/800 [==============================] - 0s 36us/step - loss: 4579.9177 - mean_absolute_error: 58.7690 - val_loss: 13413.9546 - val_mean_absolute_error: 115.5848
# Epoch 9/120
# 800/800 [==============================] - 0s 35us/step - loss: 2846.9708 - mean_absolute_error: 46.3086 - val_loss: 7576.0027 - val_mean_absolute_error: 86.8647
# Epoch 10/120
# 800/800 [==============================] - 0s 34us/step - loss: 1490.8017 - mean_absolute_error: 33.4238 - val_loss: 3421.2192 - val_mean_absolute_error: 58.3734
# Epoch 11/120
# 800/800 [==============================] - 0s 38us/step - loss: 593.6469 - mean_absolute_error: 20.9711 - val_loss: 1022.7538 - val_mean_absolute_error: 31.9163
# Epoch 12/120
# 800/800 [==============================] - 0s 35us/step - loss: 145.6145 - mean_absolute_error: 10.1632 - val_loss: 150.0932 - val_mean_absolute_error: 12.2270
# Epoch 13/120
# 800/800 [==============================] - 0s 34us/step - loss: 16.1655 - mean_absolute_error: 3.2691 - val_loss: 5.7781 - val_mean_absolute_error: 2.3994
# Epoch 14/120
# 800/800 [==============================] - 0s 37us/step - loss: 0.4802 - mean_absolute_error: 0.5298 - val_loss: 0.0075 - val_mean_absolute_error: 0.0863
# Epoch 15/120
# 800/800 [==============================] - 0s 36us/step - loss: 0.0057 - mean_absolute_error: 0.0649 - val_loss: 0.0064 - val_mean_absolute_error: 0.0790
# Epoch 16/120
# 800/800 [==============================] - 0s 50us/step - loss: 0.0039 - mean_absolute_error: 0.0522 - val_loss: 0.0071 - val_mean_absolute_error: 0.0832
# Epoch 17/120
# 800/800 [==============================] - 0s 37us/step - loss: 0.0038 - mean_absolute_error: 0.0514 - val_loss: 0.0088 - val_mean_absolute_error: 0.0930
# Epoch 18/120
# 800/800 [==============================] - 0s 36us/step - loss: 0.0038 - mean_absolute_error: 0.0516 - val_loss: 0.0074 - val_mean_absolute_error: 0.0853
# Epoch 19/120
# 800/800 [==============================] - 0s 36us/step - loss: 0.0058 - mean_absolute_error: 0.0644 - val_loss: 0.1833 - val_mean_absolute_error: 0.4268
# Epoch 20/120
# 800/800 [==============================] - 0s 41us/step - loss: 4.0064 - mean_absolute_error: 1.4280 - val_loss: 3.1871 - val_mean_absolute_error: 1.7812
# Epoch 21/120
# 800/800 [==============================] - 0s 42us/step - loss: 0.3063 - mean_absolute_error: 0.4640 - val_loss: 1.6210 - val_mean_absolute_error: 1.2702
# Epoch 22/120
# 800/800 [==============================] - 0s 42us/step - loss: 3.4435 - mean_absolute_error: 1.4620 - val_loss: 4.0015 - val_mean_absolute_error: 1.9959
# Epoch 23/120
# 800/800 [==============================] - 0s 40us/step - loss: 0.3838 - mean_absolute_error: 0.5071 - val_loss: 2.7182 - val_mean_absolute_error: 1.6450
# Epoch 24/120
# 800/800 [==============================] - 0s 38us/step - loss: 3.4480 - mean_absolute_error: 1.5344 - val_loss: 8.7611 - val_mean_absolute_error: 2.9535
# Epoch 25/120
# 800/800 [==============================] - 0s 41us/step - loss: 0.8698 - mean_absolute_error: 0.6588 - val_loss: 0.6307 - val_mean_absolute_error: 0.7922
# Epoch 26/120
# 800/800 [==============================] - 0s 38us/step - loss: 2.8924 - mean_absolute_error: 1.2561 - val_loss: 13.2218 - val_mean_absolute_error: 3.6285
# Epoch 27/120
# 800/800 [==============================] - 0s 51us/step - loss: 1.0993 - mean_absolute_error: 0.8178 - val_loss: 1.1543 - val_mean_absolute_error: 1.0718
# Epoch 28/120
# 800/800 [==============================] - 0s 39us/step - loss: 2.4442 - mean_absolute_error: 1.2348 - val_loss: 12.7594 - val_mean_absolute_error: 3.5645
# Epoch 29/120
# 800/800 [==============================] - 0s 39us/step - loss: 1.1630 - mean_absolute_error: 0.8310 - val_loss: 5.6077 - val_mean_absolute_error: 2.3629
# Epoch 30/120
# 800/800 [==============================] - 0s 36us/step - loss: 2.6977 - mean_absolute_error: 1.4132 - val_loss: 10.3570 - val_mean_absolute_error: 3.2114
# Epoch 31/120
# 800/800 [==============================] - 0s 38us/step - loss: 1.6880 - mean_absolute_error: 1.1105 - val_loss: 2.9955 - val_mean_absolute_error: 1.7269
# Epoch 32/120
# 800/800 [==============================] - 0s 38us/step - loss: 2.2795 - mean_absolute_error: 1.2741 - val_loss: 5.3458 - val_mean_absolute_error: 2.3071
# Epoch 33/120
# 800/800 [==============================] - 0s 37us/step - loss: 2.0537 - mean_absolute_error: 1.1648 - val_loss: 11.5068 - val_mean_absolute_error: 3.3850
# Epoch 34/120
# 800/800 [==============================] - 0s 37us/step - loss: 1.8616 - mean_absolute_error: 1.1763 - val_loss: 5.6822 - val_mean_absolute_error: 2.3787
# Epoch 35/120
# 800/800 [==============================] - 0s 37us/step - loss: 2.0393 - mean_absolute_error: 1.2270 - val_loss: 7.1596 - val_mean_absolute_error: 2.6701
# Epoch 36/120
# 800/800 [==============================] - 0s 35us/step - loss: 2.0499 - mean_absolute_error: 1.2343 - val_loss: 14.2378 - val_mean_absolute_error: 3.7654
# Epoch 37/120
# 800/800 [==============================] - 0s 37us/step - loss: 1.8465 - mean_absolute_error: 1.1409 - val_loss: 8.2636 - val_mean_absolute_error: 2.8686
# Epoch 38/120
# 800/800 [==============================] - 0s 37us/step - loss: 2.3765 - mean_absolute_error: 1.3326 - val_loss: 5.4666 - val_mean_absolute_error: 2.3331
# Epoch 39/120
# 800/800 [==============================] - 0s 36us/step - loss: 1.6594 - mean_absolute_error: 1.1133 - val_loss: 4.5712 - val_mean_absolute_error: 2.1335
# Epoch 40/120
# 800/800 [==============================] - 0s 36us/step - loss: 2.4329 - mean_absolute_error: 1.3261 - val_loss: 6.0579 - val_mean_absolute_error: 2.4561
# Epoch 41/120
# 800/800 [==============================] - 0s 35us/step - loss: 1.4485 - mean_absolute_error: 1.0236 - val_loss: 11.2363 - val_mean_absolute_error: 3.3450
# Epoch 42/120
# 800/800 [==============================] - 0s 34us/step - loss: 2.0601 - mean_absolute_error: 1.2221 - val_loss: 12.1724 - val_mean_absolute_error: 3.4816
# Epoch 43/120
# 800/800 [==============================] - 0s 35us/step - loss: 1.8947 - mean_absolute_error: 1.1633 - val_loss: 18.9705 - val_mean_absolute_error: 4.3465
# Epoch 44/120
# 800/800 [==============================] - 0s 40us/step - loss: 2.0843 - mean_absolute_error: 1.1946 - val_loss: 4.0088 - val_mean_absolute_error: 1.9979
# Epoch 45/120
# 800/800 [==============================] - 0s 42us/step - loss: 2.4666 - mean_absolute_error: 1.3001 - val_loss: 6.0740 - val_mean_absolute_error: 2.4594
# Epoch 46/120
# 800/800 [==============================] - 0s 39us/step - loss: 1.1832 - mean_absolute_error: 0.9199 - val_loss: 12.2039 - val_mean_absolute_error: 3.4861
# Epoch 47/120
# 800/800 [==============================] - 0s 40us/step - loss: 2.2914 - mean_absolute_error: 1.2882 - val_loss: 5.4776 - val_mean_absolute_error: 2.3355
# Epoch 48/120
# 800/800 [==============================] - 0s 63us/step - loss: 1.8741 - mean_absolute_error: 1.1883 - val_loss: 8.5213 - val_mean_absolute_error: 2.9130
# Epoch 49/120
# 800/800 [==============================] - 0s 40us/step - loss: 2.0107 - mean_absolute_error: 1.2292 - val_loss: 9.8995 - val_mean_absolute_error: 3.1398
# Epoch 50/120
# 800/800 [==============================] - 0s 40us/step - loss: 1.8138 - mean_absolute_error: 1.1117 - val_loss: 3.7689 - val_mean_absolute_error: 1.9372
# Epoch 51/120
# 800/800 [==============================] - 0s 37us/step - loss: 2.5683 - mean_absolute_error: 1.3393 - val_loss: 12.9887 - val_mean_absolute_error: 3.5965
# Epoch 52/120
# 800/800 [==============================] - 0s 38us/step - loss: 1.1566 - mean_absolute_error: 0.8833 - val_loss: 5.6950 - val_mean_absolute_error: 2.3814
# Epoch 53/120
# 800/800 [==============================] - 0s 39us/step - loss: 2.6272 - mean_absolute_error: 1.3385 - val_loss: 3.6016 - val_mean_absolute_error: 1.8938
# Epoch 54/120
# 800/800 [==============================] - 0s 41us/step - loss: 1.3280 - mean_absolute_error: 0.9506 - val_loss: 16.3001 - val_mean_absolute_error: 4.0290
# Epoch 55/120
# 800/800 [==============================] - 0s 42us/step - loss: 2.9816 - mean_absolute_error: 1.4928 - val_loss: 4.4390 - val_mean_absolute_error: 2.1025
# Epoch 56/120
# 800/800 [==============================] - 0s 43us/step - loss: 1.3237 - mean_absolute_error: 0.9649 - val_loss: 12.8486 - val_mean_absolute_error: 3.5771
# Epoch 57/120
# 800/800 [==============================] - 0s 45us/step - loss: 2.4802 - mean_absolute_error: 1.3640 - val_loss: 10.3243 - val_mean_absolute_error: 3.2065
# Epoch 58/120
# 800/800 [==============================] - 0s 42us/step - loss: 1.5513 - mean_absolute_error: 1.0542 - val_loss: 11.9973 - val_mean_absolute_error: 3.4565
# Epoch 59/120
# 800/800 [==============================] - 0s 41us/step - loss: 2.3283 - mean_absolute_error: 1.2927 - val_loss: 8.0060 - val_mean_absolute_error: 2.8236
# Epoch 60/120
# 800/800 [==============================] - 0s 39us/step - loss: 2.1309 - mean_absolute_error: 1.2620 - val_loss: 4.9258 - val_mean_absolute_error: 2.2148
# Epoch 61/120
# 800/800 [==============================] - 0s 38us/step - loss: 2.2269 - mean_absolute_error: 1.2743 - val_loss: 9.4746 - val_mean_absolute_error: 3.0717
# Epoch 62/120
# 800/800 [==============================] - 0s 43us/step - loss: 1.3832 - mean_absolute_error: 0.9701 - val_loss: 8.3560 - val_mean_absolute_error: 2.8847
# Epoch 63/120
# 800/800 [==============================] - 0s 38us/step - loss: 2.4843 - mean_absolute_error: 1.3502 - val_loss: 7.1559 - val_mean_absolute_error: 2.6695
# Epoch 64/120
# 800/800 [==============================] - 0s 45us/step - loss: 2.5636 - mean_absolute_error: 1.3283 - val_loss: 4.7453 - val_mean_absolute_error: 2.1738
# Epoch 65/120
# 800/800 [==============================] - 0s 38us/step - loss: 0.9603 - mean_absolute_error: 0.8497 - val_loss: 5.8083 - val_mean_absolute_error: 2.4050
# Epoch 66/120
# 800/800 [==============================] - 0s 43us/step - loss: 3.0387 - mean_absolute_error: 1.4857 - val_loss: 5.3796 - val_mean_absolute_error: 2.3146
# Epoch 67/120
# 800/800 [==============================] - 0s 36us/step - loss: 1.0911 - mean_absolute_error: 0.8999 - val_loss: 7.9120 - val_mean_absolute_error: 2.8070
# Epoch 68/120
# 800/800 [==============================] - 0s 39us/step - loss: 2.7433 - mean_absolute_error: 1.4311 - val_loss: 10.1082 - val_mean_absolute_error: 3.1728
# Epoch 69/120
# 800/800 [==============================] - 0s 43us/step - loss: 1.4542 - mean_absolute_error: 1.0164 - val_loss: 3.2617 - val_mean_absolute_error: 1.8023
# Epoch 70/120
# 800/800 [==============================] - 0s 42us/step - loss: 2.4856 - mean_absolute_error: 1.3289 - val_loss: 9.8349 - val_mean_absolute_error: 3.1296
# Epoch 71/120
# 800/800 [==============================] - 0s 38us/step - loss: 1.5869 - mean_absolute_error: 1.0753 - val_loss: 3.3486 - val_mean_absolute_error: 1.8261
# Epoch 72/120
# 800/800 [==============================] - 0s 45us/step - loss: 2.4361 - mean_absolute_error: 1.3106 - val_loss: 6.1335 - val_mean_absolute_error: 2.4715
# Epoch 73/120
# 800/800 [==============================] - 0s 39us/step - loss: 1.5188 - mean_absolute_error: 1.0625 - val_loss: 7.6060 - val_mean_absolute_error: 2.7522
# Epoch 74/120
# 800/800 [==============================] - 0s 40us/step - loss: 2.4607 - mean_absolute_error: 1.3584 - val_loss: 4.7751 - val_mean_absolute_error: 2.1807
# Epoch 75/120
# 800/800 [==============================] - 0s 41us/step - loss: 1.5095 - mean_absolute_error: 1.0606 - val_loss: 4.7477 - val_mean_absolute_error: 2.1744
# Epoch 76/120
# 800/800 [==============================] - 0s 42us/step - loss: 1.8385 - mean_absolute_error: 1.1353 - val_loss: 5.9381 - val_mean_absolute_error: 2.4318
# Epoch 77/120
# 800/800 [==============================] - 0s 37us/step - loss: 2.4095 - mean_absolute_error: 1.3295 - val_loss: 2.3204 - val_mean_absolute_error: 1.5201
# Epoch 78/120
# 800/800 [==============================] - 0s 56us/step - loss: 1.4555 - mean_absolute_error: 1.0141 - val_loss: 8.7954 - val_mean_absolute_error: 2.9596
# Epoch 79/120
# 800/800 [==============================] - 0s 40us/step - loss: 2.4262 - mean_absolute_error: 1.3179 - val_loss: 2.8164 - val_mean_absolute_error: 1.6747
# Epoch 80/120
# 800/800 [==============================] - 0s 40us/step - loss: 1.5762 - mean_absolute_error: 1.0102 - val_loss: 16.8486 - val_mean_absolute_error: 4.0963
# Epoch 81/120
# 800/800 [==============================] - 0s 45us/step - loss: 2.0197 - mean_absolute_error: 1.1782 - val_loss: 2.3839 - val_mean_absolute_error: 1.5408
# Epoch 82/120
# 800/800 [==============================] - 0s 38us/step - loss: 2.0573 - mean_absolute_error: 1.2230 - val_loss: 3.7365 - val_mean_absolute_error: 1.9290
# Epoch 83/120
# 800/800 [==============================] - 0s 39us/step - loss: 1.7756 - mean_absolute_error: 1.1265 - val_loss: 12.7803 - val_mean_absolute_error: 3.5677
# Epoch 84/120
# 800/800 [==============================] - 0s 39us/step - loss: 1.9115 - mean_absolute_error: 1.1612 - val_loss: 14.2130 - val_mean_absolute_error: 3.7623
# Epoch 85/120
# 800/800 [==============================] - 0s 44us/step - loss: 1.8540 - mean_absolute_error: 1.1028 - val_loss: 2.3075 - val_mean_absolute_error: 1.5159
# Epoch 86/120
# 800/800 [==============================] - 0s 40us/step - loss: 2.0607 - mean_absolute_error: 1.2047 - val_loss: 11.3905 - val_mean_absolute_error: 3.3681
# Epoch 87/120
# 800/800 [==============================] - 0s 40us/step - loss: 1.9724 - mean_absolute_error: 1.1811 - val_loss: 1.4647 - val_mean_absolute_error: 1.2078
# Epoch 88/120
# 800/800 [==============================] - 0s 41us/step - loss: 1.7354 - mean_absolute_error: 1.0999 - val_loss: 9.5032 - val_mean_absolute_error: 3.0765
# Epoch 89/120
# 800/800 [==============================] - 0s 41us/step - loss: 1.7905 - mean_absolute_error: 1.1418 - val_loss: 11.2233 - val_mean_absolute_error: 3.3433
# Epoch 90/120
# 800/800 [==============================] - 0s 40us/step - loss: 1.8014 - mean_absolute_error: 1.0483 - val_loss: 4.1358 - val_mean_absolute_error: 2.0295
# Epoch 91/120
# 800/800 [==============================] - 0s 41us/step - loss: 2.8577 - mean_absolute_error: 1.4003 - val_loss: 3.7050 - val_mean_absolute_error: 1.9209
# Epoch 92/120
# 800/800 [==============================] - 0s 42us/step - loss: 0.8726 - mean_absolute_error: 0.7823 - val_loss: 7.8635 - val_mean_absolute_error: 2.7985
# Epoch 93/120
# 800/800 [==============================] - 0s 38us/step - loss: 2.8700 - mean_absolute_error: 1.4384 - val_loss: 2.8000 - val_mean_absolute_error: 1.6699
# Epoch 94/120
# 800/800 [==============================] - 0s 43us/step - loss: 1.0528 - mean_absolute_error: 0.8731 - val_loss: 7.1782 - val_mean_absolute_error: 2.6738
# Epoch 95/120
# 800/800 [==============================] - 0s 38us/step - loss: 2.3743 - mean_absolute_error: 1.3151 - val_loss: 4.7705 - val_mean_absolute_error: 2.1797
# Epoch 96/120
# 800/800 [==============================] - 0s 41us/step - loss: 1.6468 - mean_absolute_error: 1.1073 - val_loss: 11.8896 - val_mean_absolute_error: 3.4411
# Epoch 97/120
# 800/800 [==============================] - 0s 38us/step - loss: 1.9871 - mean_absolute_error: 1.1868 - val_loss: 3.7846 - val_mean_absolute_error: 1.9415
# Epoch 98/120
# 800/800 [==============================] - 0s 42us/step - loss: 2.4329 - mean_absolute_error: 1.2995 - val_loss: 5.5528 - val_mean_absolute_error: 2.3517
# Epoch 99/120
# 800/800 [==============================] - 0s 43us/step - loss: 1.0141 - mean_absolute_error: 0.8581 - val_loss: 11.1057 - val_mean_absolute_error: 3.3258
# Epoch 100/120
# 800/800 [==============================] - 0s 45us/step - loss: 2.5077 - mean_absolute_error: 1.3620 - val_loss: 5.3515 - val_mean_absolute_error: 2.3086
# Epoch 101/120
# 800/800 [==============================] - 0s 38us/step - loss: 1.6259 - mean_absolute_error: 1.1058 - val_loss: 6.0837 - val_mean_absolute_error: 2.4615
# Epoch 102/120
# 800/800 [==============================] - 0s 36us/step - loss: 2.2595 - mean_absolute_error: 1.2895 - val_loss: 10.5355 - val_mean_absolute_error: 3.2393
# Epoch 103/120
# 800/800 [==============================] - 0s 38us/step - loss: 1.4965 - mean_absolute_error: 1.0333 - val_loss: 3.7330 - val_mean_absolute_error: 1.9282
# Epoch 104/120
# 800/800 [==============================] - 0s 44us/step - loss: 2.7283 - mean_absolute_error: 1.3427 - val_loss: 11.2071 - val_mean_absolute_error: 3.3409
# Epoch 105/120
# 800/800 [==============================] - 0s 42us/step - loss: 0.7452 - mean_absolute_error: 0.6972 - val_loss: 6.9957 - val_mean_absolute_error: 2.6396
# Epoch 106/120
# 800/800 [==============================] - 0s 42us/step - loss: 2.6004 - mean_absolute_error: 1.3587 - val_loss: 3.1537 - val_mean_absolute_error: 1.7722
# Epoch 107/120
# 800/800 [==============================] - 0s 38us/step - loss: 1.5068 - mean_absolute_error: 1.0527 - val_loss: 9.5861 - val_mean_absolute_error: 3.0899
# Epoch 108/120
# 800/800 [==============================] - 0s 56us/step - loss: 2.3052 - mean_absolute_error: 1.3064 - val_loss: 3.3428 - val_mean_absolute_error: 1.8246
# Epoch 109/120
# 800/800 [==============================] - 0s 40us/step - loss: 1.4908 - mean_absolute_error: 0.9667 - val_loss: 24.1588 - val_mean_absolute_error: 4.9052
# Epoch 110/120
# 800/800 [==============================] - 0s 39us/step - loss: 1.7950 - mean_absolute_error: 1.0144 - val_loss: 3.7036 - val_mean_absolute_error: 1.9206
# Epoch 111/120
# 800/800 [==============================] - 0s 36us/step - loss: 2.3348 - mean_absolute_error: 1.2894 - val_loss: 12.5689 - val_mean_absolute_error: 3.5381
# Epoch 112/120
# 800/800 [==============================] - 0s 38us/step - loss: 1.6031 - mean_absolute_error: 1.0842 - val_loss: 6.2127 - val_mean_absolute_error: 2.4875
# Epoch 113/120
# 800/800 [==============================] - 0s 44us/step - loss: 2.3749 - mean_absolute_error: 1.3124 - val_loss: 6.6814 - val_mean_absolute_error: 2.5796
# Epoch 114/120
# 800/800 [==============================] - 0s 41us/step - loss: 1.2952 - mean_absolute_error: 0.9684 - val_loss: 10.7309 - val_mean_absolute_error: 3.2692
# Epoch 115/120
# 800/800 [==============================] - 0s 40us/step - loss: 2.1389 - mean_absolute_error: 1.1966 - val_loss: 2.3578 - val_mean_absolute_error: 1.5324
# Epoch 116/120
# 800/800 [==============================] - 0s 50us/step - loss: 1.6849 - mean_absolute_error: 1.0857 - val_loss: 14.3843 - val_mean_absolute_error: 3.7850
# Epoch 117/120
# 800/800 [==============================] - 0s 40us/step - loss: 2.2805 - mean_absolute_error: 1.2789 - val_loss: 1.5581 - val_mean_absolute_error: 1.2457
# Epoch 118/120
# 800/800 [==============================] - 0s 38us/step - loss: 1.5364 - mean_absolute_error: 1.0223 - val_loss: 11.0302 - val_mean_absolute_error: 3.3144
# Epoch 119/120
# 800/800 [==============================] - 0s 36us/step - loss: 1.7573 - mean_absolute_error: 1.1163 - val_loss: 9.8766 - val_mean_absolute_error: 3.1363
# Epoch 120/120
# 800/800 [==============================] - 0s 39us/step - loss: 2.2682 - mean_absolute_error: 1.2565 - val_loss: 2.2934 - val_mean_absolute_error: 1.5113

# %%
plot_metric(h,"loss")

# %%
err_tr = np.mean(h.history['loss'][-40:])
err_vl = np.mean(h.history['val_loss'][-40:])

# %%
err_tr, err_vl
# Out:
# (1.910558561142534, 7.433360321819782)

# %%
def scale(x):
  return (x - x.min() / float(x.max() - x.min()))

def build(capas):
  m = models.Sequential()
  m.add(layers.Dense(units = 64,activation = "elu",input_shape = (1,)))
  for i in np.arange(capas):
    m.add(layers.Dense(units = 10,activation = "elu"))
  m.add(layers.Dense(units = 1,activation = None))
  m.compile(loss = losses.mse,optimizer = optimizers.rmsprop(),metrics = [metrics.mean_absolute_error])
  return m

# %%
e_tr = []
e_vl = []
capas = np.arange(0,10,1)
model_list = []
for n in capas:
  n = build(n)
  h = m.fit(x = scale(x_train),y = y_train,batch_size = 100,epochs = 120,validation_split = 0.2,verbose = 0)
  e_tr.append(np.mean(h.history['loss'][-40:]))
  e_vl.append(np.mean(h.history['val_loss'][-40:]))
  model_list.append(m)

# %%
plt.semilogy(capas,e_tr,"--r")
plt.semilogy(capas,e_vl,"--b")
plt.show()

# %%
m = model_list[3]
pred = m.predict(scale(x_train))
plt.plot()

# %% [markdown]
# ### And now even a more complex one
#
# Let's try to predict now this function:
#
# $\displaystyle y = \cos(x)$
